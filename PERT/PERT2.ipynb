# %%
import pandas as pd
import pert

# %%
# Ejemplo de uso
df = pd.DataFrame({
    'Nombre actividad': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
    'Duración': [3, 6, 7, 5, 13, 8, 11, 6],
    'Predecesores': ['', 'A', 'A', 'A', 'B,C', 'C,D', 'D,F', 'G,E']
})

# %%
ruta=pert.find_critical_path(df)
ruta
# Out:
# ['A', 'C', 'F', 'G', 'H']

# %%
tiempos, duracion ,figura =pert.draw_pert_graph(df)

# %%
tiempos
# Out:
#   Nombre actividad  Duración Tiempos Tempranos Tiempos Tardíos  Inicio  Fin
# 0                A         3               0|3             0|3       0    3
# 1                B         6               3|9           10|16       3    9
# 2                C         7              3|10            3|10       3   10
# 3                D         5               3|8            5|10       3    8
# 4                E        13             10|23           16|29      10   23
# 5                F         8             10|18           10|18      10   18
# 6                G        11             18|29           18|29      18   29
# 7                H         6             29|35           29|35      29   35

# %%
duracion
# Out:
# 35
